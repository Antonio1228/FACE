# %%
configs = [
    {
        "file_path": "C64/randoms/nojaccard_procrustes.csv",
        "match_file_path": "C64/randoms/nojaccard_procrustes.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/randoms/noprocrustes_EMD.csv",
        "match_file_path": "C64/randoms/noprocrustes_EMD.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/randoms/nojaccard_EMD.csv",
        "match_file_path": "C64/randoms/nojaccard_EMD.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noprocrustes_knn.csv",
        "match_file_path": "C64/randoms/noprocrustes_knn.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/randoms/nojaccard_knn.csv",
        "match_file_path": "C64/randoms/nojaccard_knn.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noknn_EMD.csv",
        "match_file_path": "C64/randoms/noknn_EMD.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noprocrustes_density.csv",
        "match_file_path": "C64/randoms/noprocrustes_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/randoms/nojaccard_density.csv",
        "match_file_path": "C64/randoms/nojaccard_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noEMD_density.csv",
        "match_file_path": "C64/randoms/noEMD_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noknn_density.csv",
        "match_file_path": "C64/randoms/noknn_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noeuclidean_procrustes.csv",
        "match_file_path": "C64/randoms/noeuclidean_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/randoms/nojaccard_euclidean.csv",
        "match_file_path": "C64/randoms/nojaccard_euclidean.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noeuclidean_EMD.csv",
        "match_file_path": "C64/randoms/noeuclidean_EMD.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noeuclidean_knn.csv",
        "match_file_path": "C64/randoms/noeuclidean_knn.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/randoms/noeuclidean_density.csv",
        "match_file_path": "C64/randoms/noeuclidean_density.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
]

# %%
import os
import papermill as pm

image_folder_path = 'human_picture'  
notebook_path = 'face(all_points)_mark2(not_for_demo,csv)copy.ipynb'  # Notebook 文件



output_notebook_path = 'processed_output.ipynb'

for config in configs:
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path1 = os.path.join(image_folder_path, filename)
            
            
            pm.execute_notebook(
                notebook_path,
                output_notebook_path,  
                parameters={
                    'image_path1': image_path1,
                    'file_path': config['file_path'],
                    'match_file_path': config['match_file_path'],
                    'weights': config['weights']
                }
            )

# %%
configs = [
    {
        "file_path": "C64/bfs/nojaccard_procrustes.csv",
        "match_file_path": "C64/bfs/nojaccard_procrustes.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/bfs/noprocrustes_EMD.csv",
        "match_file_path": "C64/bfs/noprocrustes_EMD.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/bfs/nojaccard_EMD.csv",
        "match_file_path": "C64/bfs/nojaccard_EMD.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noprocrustes_knn.csv",
        "match_file_path": "C64/bfs/noprocrustes_knn.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/bfs/nojaccard_knn.csv",
        "match_file_path": "C64/bfs/nojaccard_knn.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noknn_EMD.csv",
        "match_file_path": "C64/bfs/noknn_EMD.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0.25,
            "knn": 0,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noprocrustes_density.csv",
        "match_file_path": "C64/bfs/noprocrustes_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/bfs/nojaccard_density.csv",
        "match_file_path": "C64/bfs/nojaccard_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noEMD_density.csv",
        "match_file_path": "C64/bfs/noEMD_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noknn_density.csv",
        "match_file_path": "C64/bfs/noknn_density.csv",
        "weights": {
            "euclidean": 0.25,
            "density": 0,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noeuclidean_procrustes.csv",
        "match_file_path": "C64/bfs/noeuclidean_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C64/bfs/nojaccard_euclidean.csv",
        "match_file_path": "C64/bfs/nojaccard_euclidean.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noeuclidean_EMD.csv",
        "match_file_path": "C64/bfs/noeuclidean_EMD.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0.25,
            "EMD": 0,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noeuclidean_knn.csv",
        "match_file_path": "C64/bfs/noeuclidean_knn.csv",
        "weights": {
            "euclidean": 0,
            "density": 0.25,
            "knn": 0,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
    {
        "file_path": "C64/bfs/noeuclidean_density.csv",
        "match_file_path": "C64/bfs/noeuclidean_density.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 0.25,
            "EMD": 0.25,
            "jaccard": 0.25,
            "procrustes": 0.25,
        },
    },
]

# %%
import os
import papermill as pm

image_folder_path = 'human_picture'  
notebook_path = 'face(all_points,bfs,not_for_demo)copy.ipynb'  # Notebook 文件



output_notebook_path = 'processed_output.ipynb'

for config in configs:
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path1 = os.path.join(image_folder_path, filename)
            
            
            pm.execute_notebook(
                notebook_path,
                output_notebook_path,  
                parameters={
                    'image_path1': image_path1,
                    'file_path': config['file_path'],
                    'match_file_path': config['match_file_path'],
                    'weights': config['weights']
                }
            )
