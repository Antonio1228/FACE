# %%
configs = [
    {
        "file_path": "C63/randoms/EMD_jaccard_procrustes.csv",
        "match_file_path": "C63/randoms/EMD_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
]

# %%
import os
import papermill as pm

image_folder_path = 'human_picture'  
notebook_path = 'face(all_points)_mark2(not_for_demo,csv)copy.ipynb'  # Notebook 文件



output_notebook_path = 'processed_output.ipynb'

for config in configs:
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path1 = os.path.join(image_folder_path, filename)
            
            
            pm.execute_notebook(
                notebook_path,
                output_notebook_path,  
                parameters={
                    'image_path1': image_path1,
                    'file_path': config['file_path'],
                    'match_file_path': config['match_file_path'],
                    'weights': config['weights']
                }
            )

# %%
configs = [
    {
        "file_path": "C63/bfs/euclidean_density_jaccard.csv",
        "match_file_path": "C63/bfs/euclidean_density_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_density_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_density_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_knn_EMD.csv",
        "match_file_path": "C63/bfs/euclidean_knn_EMD.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_knn_jaccard.csv",
        "match_file_path": "C63/bfs/euclidean_knn_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_knn_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_knn_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_EMD_jaccard.csv",
        "match_file_path": "C63/bfs/euclidean_EMD_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_EMD_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_EMD_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/density_knn_EMD.csv",
        "match_file_path": "C63/bfs/density_knn_EMD.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/density_knn_jaccard.csv",
        "match_file_path": "C63/bfs/density_knn_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/density_knn_procrustes.csv",
        "match_file_path": "C63/bfs/density_knn_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/density_EMD_jaccard.csv",
        "match_file_path": "C63/bfs/density_EMD_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/density_EMD_procrustes.csv",
        "match_file_path": "C63/bfs/density_EMD_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/density_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/density_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/knn_EMD_jaccard.csv",
        "match_file_path": "C63/bfs/knn_EMD_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/knn_EMD_procrustes.csv",
        "match_file_path": "C63/bfs/knn_EMD_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/knn_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/knn_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/EMD_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/EMD_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
]

# %%
import os
import papermill as pm

image_folder_path = 'human_picture'  
notebook_path = 'face(all_points,bfs,not_for_demo)copy.ipynb'  # Notebook 文件



output_notebook_path = 'processed_output.ipynb'

for config in configs:
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path1 = os.path.join(image_folder_path, filename)
            
            
            pm.execute_notebook(
                notebook_path,
                output_notebook_path,  
                parameters={
                    'image_path1': image_path1,
                    'file_path': config['file_path'],
                    'match_file_path': config['match_file_path'],
                    'weights': config['weights']
                }
            )

# %%
import os
import pandas as pd

def process_csv_files(root_dirs):
    # 遍历所有顶级文件夹
    for root_dir in root_dirs:
        print(f"Processing directory: {root_dir}")
        # 确定子文件夹 'bfs' 和 'randoms'
        subfolders = ['bfs', 'randoms']
        for subfolder in subfolders:
            subfolder_path = os.path.join(root_dir, subfolder)
            if not os.path.isdir(subfolder_path):
                print(f"Subdirectory {subfolder_path} not found.")
                continue
            
            print(f"Processing subdirectory: {subfolder_path}")
            # 处理子文件夹中的每个 CSV 文件
            for file_name in os.listdir(subfolder_path):
                if file_name.endswith('.csv'):
                    file_path = os.path.join(subfolder_path, file_name)
                    try:
                        # 读取 CSV 文件并计算列的总和
                        match_data = pd.read_csv(file_path)
                        individual_sums = match_data[['eye', 'emo', 'mouth']].sum()
                        print(f"Sums for {file_path}:")
                        print(individual_sums)
                    except Exception as e:
                        print(f"Error processing file {file_path}: {e}")

# 列出所有顶级文件夹
top_folders = ['C62', 'C63', 'C64', 'C65']
top_folder_paths = [os.path.join(os.getcwd(), folder) for folder in top_folders]

process_csv_files(top_folder_paths)
# Out:
# Processing directory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C62
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\density_EMD.csv:
# eye      42.0
# emo      12.0
# mouth    53.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\density_jaccard.csv:
# eye      42.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\density_knn.csv:
# eye      55.0
# emo      43.0
# mouth    62.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\density_procrustes.csv:
# eye      55.0
# emo      44.0
# mouth    38.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\EMD_jaccard.csv:
# eye      46.0
# emo       5.0
# mouth    59.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\EMD_procrustes.csv:
# eye      48.0
# emo      10.0
# mouth    36.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\euclidean_density.csv:
# eye      44.0
# emo       3.0
# mouth    49.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\euclidean_EMD.csv:
# eye      46.0
# emo      26.0
# mouth    52.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\euclidean_jaccard.csv:
# eye      44.0
# emo       7.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\euclidean_knn.csv:
# eye      47.0
# emo       9.0
# mouth    51.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\euclidean_procrustes.csv:
# eye      46.0
# emo       2.0
# mouth    63.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\jaccard_procrustes.csv:
# eye      44.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\knn_EMD.csv:
# eye      46.0
# emo      28.0
# mouth    49.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\knn_jaccard.csv:
# eye      44.0
# emo       8.0
# mouth    61.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\bfs\knn_procrustes.csv:
# eye      54.0
# emo      43.0
# mouth    41.0
# dtype: float64
# Subdirectory c:\Users\09350\OneDrive\文件\GitHub\FACE\C62\randoms not found.
# Processing directory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C63
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\density_EMD_jaccard.csv:
# eye      45.0
# emo       5.0
# mouth    57.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\density_EMD_procrustes.csv:
# eye      46.0
# emo       6.0
# mouth    54.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\density_jaccard_procrustes.csv:
# eye      44.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\density_knn_EMD.csv:
# eye      44.0
# emo      10.0
# mouth    54.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\density_knn_jaccard.csv:
# eye      42.0
# emo       6.0
# mouth    64.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\density_knn_procrustes.csv:
# eye      55.0
# emo      44.0
# mouth    58.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\EMD_jaccard_procrustes.csv:
# eye      46.0
# emo       5.0
# mouth    59.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_density_EMD.csv:
# eye      40.0
# emo      11.0
# mouth    47.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_density_jaccard.csv:
# eye      42.0
# emo       6.0
# mouth    64.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_density_knn.csv:
# eye      42.0
# emo       2.0
# mouth    50.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_density_procrustes.csv:
# eye      41.0
# emo       4.0
# mouth    53.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_EMD_jaccard.csv:
# eye      47.0
# emo       7.0
# mouth    58.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_EMD_procrustes.csv:
# eye      45.0
# emo      13.0
# mouth    44.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_jaccard_procrustes.csv:
# eye      42.0
# emo       5.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_knn_EMD.csv:
# eye      45.0
# emo      25.0
# mouth    53.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_knn_jaccard.csv:
# eye      46.0
# emo       7.0
# mouth    64.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\euclidean_knn_procrustes.csv:
# eye      47.0
# emo       5.0
# mouth    58.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\knn_EMD_jaccard.csv:
# eye      46.0
# emo       5.0
# mouth    55.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\knn_EMD_procrustes.csv:
# eye      45.0
# emo      10.0
# mouth    40.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\bfs\knn_jaccard_procrustes.csv:
# eye      45.0
# emo       6.0
# mouth    64.0
# dtype: float64
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\density_EMD_jaccard.csv:
# eye      41.0
# emo       4.0
# mouth    67.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\density_EMD_procrustes.csv:
# eye      42.0
# emo       9.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\density_jaccard_procrustes.csv:
# eye      56.0
# emo       2.0
# mouth    70.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\density_knn_EMD.csv:
# eye      40.0
# emo       6.0
# mouth    74.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\density_knn_jaccard.csv:
# eye      50.0
# emo       1.0
# mouth    69.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\density_knn_procrustes.csv:
# eye      44.0
# emo      41.0
# mouth    61.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\EMD_jaccard_procrustes.csv:
# eye      42.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_density_EMD.csv:
# eye      39.0
# emo       8.0
# mouth    63.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_density_jaccard.csv:
# eye      52.0
# emo       0.0
# mouth    67.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_density_knn.csv:
# eye      48.0
# emo      23.0
# mouth    76.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_density_procrustes.csv:
# eye      45.0
# emo      37.0
# mouth    70.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_EMD_jaccard.csv:
# eye      43.0
# emo       3.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_EMD_procrustes.csv:
# eye      43.0
# emo       4.0
# mouth    62.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_jaccard_procrustes.csv:
# eye      53.0
# emo       1.0
# mouth    69.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_knn_EMD.csv:
# eye      44.0
# emo       7.0
# mouth    61.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_knn_jaccard.csv:
# eye      55.0
# emo       0.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\euclidean_knn_procrustes.csv:
# eye      45.0
# emo       8.0
# mouth    69.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\knn_EMD_jaccard.csv:
# eye      41.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\knn_EMD_procrustes.csv:
# eye      39.0
# emo       4.0
# mouth    61.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C63\randoms\knn_jaccard_procrustes.csv:
# eye      55.0
# emo       1.0
# mouth    70.0
# dtype: float64
# Processing directory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C64
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noEMD_density.csv:
# eye      42.0
# emo       6.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noeuclidean_density.csv:
# eye      46.0
# emo       5.0
# mouth    56.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noeuclidean_EMD.csv:
# eye      44.0
# emo       4.0
# mouth    62.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noeuclidean_knn.csv:
# eye      47.0
# emo       5.0
# mouth    54.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noeuclidean_procrustes.csv:
# eye      45.0
# emo       5.0
# mouth    55.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\nojaccard_density.csv:
# eye      43.0
# emo      14.0
# mouth    45.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\nojaccard_EMD.csv:
# eye      42.0
# emo       7.0
# mouth    55.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\nojaccard_euclidean.csv:
# eye      47.0
# emo       8.0
# mouth    54.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\nojaccard_knn.csv:
# eye      41.0
# emo       8.0
# mouth    53.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\nojaccard_procrustes.csv:
# eye      39.0
# emo      11.0
# mouth    48.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noknn_density.csv:
# eye      46.0
# emo       6.0
# mouth    57.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noknn_EMD.csv:
# eye      41.0
# emo       5.0
# mouth    63.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noprocrustes_density.csv:
# eye      46.0
# emo       7.0
# mouth    56.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noprocrustes_EMD.csv:
# eye      43.0
# emo       5.0
# mouth    62.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\bfs\noprocrustes_knn.csv:
# eye      46.0
# emo       6.0
# mouth    53.0
# dtype: float64
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noEMD_density.csv:
# eye      54.0
# emo       1.0
# mouth    70.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noeuclidean_density.csv:
# eye      42.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noeuclidean_EMD.csv:
# eye      52.0
# emo       2.0
# mouth    69.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noeuclidean_knn.csv:
# eye      40.0
# emo       4.0
# mouth    67.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noeuclidean_procrustes.csv:
# eye      41.0
# emo       4.0
# mouth    67.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\nojaccard_density.csv:
# eye      44.0
# emo       5.0
# mouth    62.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\nojaccard_EMD.csv:
# eye      50.0
# emo      38.0
# mouth    68.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\nojaccard_euclidean.csv:
# eye      40.0
# emo       9.0
# mouth    69.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\nojaccard_knn.csv:
# eye      41.0
# emo       6.0
# mouth    63.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\nojaccard_procrustes.csv:
# eye      39.0
# emo       7.0
# mouth    67.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noknn_density.csv:
# eye      42.0
# emo       3.0
# mouth    64.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noknn_EMD.csv:
# eye      53.0
# emo       1.0
# mouth    68.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noprocrustes_density.csv:
# eye      42.0
# emo       4.0
# mouth    64.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noprocrustes_EMD.csv:
# eye      50.0
# emo       1.0
# mouth    67.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C64\randoms\noprocrustes_knn.csv:
# eye      43.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Processing directory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C65
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs\nodensity.csv:
# eye      47.0
# emo       6.0
# mouth    56.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs\noEMD.csv:
# eye      42.0
# emo       5.0
# mouth    61.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs\noeuclidean.csv:
# eye      46.0
# emo       5.0
# mouth    52.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs\nojaccard.csv:
# eye      42.0
# emo       8.0
# mouth    53.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs\noknn.csv:
# eye      46.0
# emo       6.0
# mouth    52.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\bfs\noprocrustes.csv:
# eye      46.0
# emo       7.0
# mouth    51.0
# dtype: float64
# Processing subdirectory: c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms\nodensity.csv:
# eye      43.0
# emo       4.0
# mouth    64.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms\noEMD.csv:
# eye      52.0
# emo       1.0
# mouth    69.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms\noeuclidean.csv:
# eye      41.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms\nojaccard.csv:
# eye      38.0
# emo       7.0
# mouth    65.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms\noknn.csv:
# eye      40.0
# emo       4.0
# mouth    66.0
# dtype: float64
# Sums for c:\Users\09350\OneDrive\文件\GitHub\FACE\C65\randoms\noprocrustes.csv:
# eye      40.0
# emo       4.0
# mouth    67.0
# dtype: float64
