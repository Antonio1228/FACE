# %%
configs = [
    {
        "file_path": "C63/randoms/euclidean_density_knn.csv",
        "match_file_path": "C63/randoms/euclidean_density_knn.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_density_EMD.csv",
        "match_file_path": "C63/randoms/euclidean_density_EMD.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_density_jaccard.csv",
        "match_file_path": "C63/randoms/euclidean_density_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_density_procrustes.csv",
        "match_file_path": "C63/randoms/euclidean_density_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_knn_EMD.csv",
        "match_file_path": "C63/randoms/euclidean_knn_EMD.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_knn_jaccard.csv",
        "match_file_path": "C63/randoms/euclidean_knn_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_knn_procrustes.csv",
        "match_file_path": "C63/randoms/euclidean_knn_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_EMD_jaccard.csv",
        "match_file_path": "C63/randoms/euclidean_EMD_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_EMD_procrustes.csv",
        "match_file_path": "C63/randoms/euclidean_EMD_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/euclidean_jaccard_procrustes.csv",
        "match_file_path": "C63/randoms/euclidean_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/density_knn_EMD.csv",
        "match_file_path": "C63/randoms/density_knn_EMD.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/density_knn_jaccard.csv",
        "match_file_path": "C63/randoms/density_knn_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/density_knn_procrustes.csv",
        "match_file_path": "C63/randoms/density_knn_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/density_EMD_jaccard.csv",
        "match_file_path": "C63/randoms/density_EMD_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/density_EMD_procrustes.csv",
        "match_file_path": "C63/randoms/density_EMD_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/density_jaccard_procrustes.csv",
        "match_file_path": "C63/randoms/density_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/knn_EMD_jaccard.csv",
        "match_file_path": "C63/randoms/knn_EMD_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/randoms/knn_EMD_procrustes.csv",
        "match_file_path": "C63/randoms/knn_EMD_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/knn_jaccard_procrustes.csv",
        "match_file_path": "C63/randoms/knn_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/randoms/EMD_jaccard_procrustes.csv",
        "match_file_path": "C63/randoms/EMD_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
]

# %%
import os
import papermill as pm

image_folder_path = 'human_picture'  
notebook_path = 'face(all_points)_mark2(not_for_demo,csv)copy.ipynb'  # Notebook 文件



output_notebook_path = 'processed_output.ipynb'

for config in configs:
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path1 = os.path.join(image_folder_path, filename)
            
            
            pm.execute_notebook(
                notebook_path,
                output_notebook_path,  
                parameters={
                    'image_path1': image_path1,
                    'file_path': config['file_path'],
                    'match_file_path': config['match_file_path'],
                    'weights': config['weights']
                }
            )

# %%
configs = [
    {
        "file_path": "C63/bfs/euclidean_density_knn.csv",
        "match_file_path": "C63/bfs/euclidean_density_knn.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_density_EMD.csv",
        "match_file_path": "C63/bfs/euclidean_density_EMD.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_density_jaccard.csv",
        "match_file_path": "C63/bfs/euclidean_density_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_density_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_density_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_knn_EMD.csv",
        "match_file_path": "C63/bfs/euclidean_knn_EMD.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_knn_jaccard.csv",
        "match_file_path": "C63/bfs/euclidean_knn_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_knn_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_knn_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_EMD_jaccard.csv",
        "match_file_path": "C63/bfs/euclidean_EMD_jaccard.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_EMD_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_EMD_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/euclidean_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/euclidean_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 1/3,
            "density": 0,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/density_knn_EMD.csv",
        "match_file_path": "C63/bfs/density_knn_EMD.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/density_knn_jaccard.csv",
        "match_file_path": "C63/bfs/density_knn_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/density_knn_procrustes.csv",
        "match_file_path": "C63/bfs/density_knn_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/density_EMD_jaccard.csv",
        "match_file_path": "C63/bfs/density_EMD_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/density_EMD_procrustes.csv",
        "match_file_path": "C63/bfs/density_EMD_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/density_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/density_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 1/3,
            "knn": 0,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/knn_EMD_jaccard.csv",
        "match_file_path": "C63/bfs/knn_EMD_jaccard.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 0,
        },
    },
    {
        "file_path": "C63/bfs/knn_EMD_procrustes.csv",
        "match_file_path": "C63/bfs/knn_EMD_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 1/3,
            "jaccard": 0,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/knn_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/knn_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 1/3,
            "EMD": 0,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
    {
        "file_path": "C63/bfs/EMD_jaccard_procrustes.csv",
        "match_file_path": "C63/bfs/EMD_jaccard_procrustes.csv",
        "weights": {
            "euclidean": 0,
            "density": 0,
            "knn": 0,
            "EMD": 1/3,
            "jaccard": 1/3,
            "procrustes": 1/3,
        },
    },
]

# %%
import os
import papermill as pm

image_folder_path = 'human_picture'  
notebook_path = 'face(all_points,bfs,not_for_demo)copy.ipynb'  # Notebook 文件



output_notebook_path = 'processed_output.ipynb'

for config in configs:
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path1 = os.path.join(image_folder_path, filename)
            
            
            pm.execute_notebook(
                notebook_path,
                output_notebook_path,  
                parameters={
                    'image_path1': image_path1,
                    'file_path': config['file_path'],
                    'match_file_path': config['match_file_path'],
                    'weights': config['weights']
                }
            )
